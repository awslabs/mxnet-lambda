# %% [markdown]
# # Building a prediction API using a pre-trained MXNet model

# %%
'''
Reference code to showcase MXNet model prediction on AWS Lambda.

This function uses the geolocation model and predicts the lat/long for a given image and then
using the geopy module, we reserve map that to a location - country/city

@author: Sunil Mallya
'''

import base64
import os
import boto3
import json
import tempfile
import urllib2 
from urllib import urlretrieve

# Check if Lambda Function
if os.environ.get('LAMBDA_TASK_ROOT') is None:
    print "just exit, we are not in a lambda function",
    import sys; sys.exit(0)
    
from geopy.geocoders import Nominatim
geolocator = Nominatim()
    
# del all files in tmp directory - just in case
import os
for f in os.listdir("/tmp"):
    f_path = "/tmp/" + f
    os.unlink(f_path)

import mxnet as mx
import numpy as np

from PIL import Image
from io import BytesIO
from collections import namedtuple
Batch = namedtuple('Batch', ['data'])

# Gloabls
grids, ground_truth = [], {}

f_params = 'geo/RN101-5k500-0012.params'
f_symbol = 'geo/RN101-5k500-symbol.json'
    
bucket = 'smallya-test'
s3 = boto3.resource('s3')
s3_client = boto3.client('s3')

# load labels
with open('grids.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        lat = float(line[1])
        lng = float(line[2])
        grids.append((lat, lng))

# Load model
def load_model(s_fname, p_fname):
    """
    Load model checkpoint from file.
    :return: (arg_params, aux_params)
    arg_params : dict of str to NDArray
        Model parameter, dict of name to NDArray of net's weights.
    aux_params : dict of str to NDArray
        Model parameter, dict of name to NDArray of net's auxiliary states.
    """
    symbol = mx.symbol.load(s_fname)
    save_dict = mx.nd.load(p_fname)
    arg_params = {}
    aux_params = {}
    for k, v in save_dict.items():
        tp, name = k.split(':', 1)
        if tp == 'arg':
            arg_params[name] = v
        if tp == 'aux':
            aux_params[name] = v
    return symbol, arg_params, aux_params

# load labels
with open('grids.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        lat = float(line[1])
        lng = float(line[2])
        grids.append((lat, lng))
   
mod = None

#params
f_params_file = tempfile.NamedTemporaryFile(delete=True)
urlretrieve("https://s3.amazonaws.com/smallya-test/geo/RN101-5k500-0012.params", f_params_file.name)
f_params_file.flush()

#symbol
f_symbol_file = tempfile.NamedTemporaryFile(delete=True)
urlretrieve("https://s3.amazonaws.com/smallya-test/geo/RN101-5k500-symbol.json", f_symbol_file.name)
f_symbol_file.flush()

sym, arg_params, aux_params = load_model(f_symbol_file.name, f_params_file.name)
mod = mx.mod.Module(symbol=sym, label_names=None)
mod.bind(for_training=False, data_shapes=[('data', (1,3,224,224))], label_shapes=mod._label_shapes)
mod.set_params(arg_params, aux_params, allow_missing=True)

f_params_file.close()
f_symbol_file.close()

### Helpers
def distance(p1, p2):
        R = 6371 # Earth radius in km
        lat1, lng1, lat2, lng2 = map(radians, (p1[0], p1[1], p2[0], p2[1]))
        dlat = lat2 - lat1
        dlng = lng2 - lng1
        a = sin(dlat * 0.5) ** 2 + cos(lat1) * cos(lat2) * (sin(dlng * 0.5) ** 2)
        return 2 * R * asin(sqrt(a))

# mean image for preprocessing
mean_rgb = np.array([123.68, 116.779, 103.939])
mean_rgb = mean_rgb.reshape((3, 1, 1))

def predict(url, dataurl):
    '''
    predict labels for a given image
    '''

    print "downloading the image"
    img_file = tempfile.NamedTemporaryFile(delete=True)
    if url:
        req = urllib2.urlopen(url)
        img_file.write(req.read())
        img_file.flush()
        img = Image.open(img_file.name)
    elif dataurl:
        #convert to image
        img_data = dataurl.split(",")[1]
        if img_data[-2] != "=":
            img_data += "=" # pad it 
        img = Image.open(BytesIO(base64.b64decode(img_data))) 
        img = img.convert('RGB')

    img_file.close()
    
    # center crop and no resize
    # ** width, height must be greater than new_width, new_height 
    #new_width, new_height = 224, 224
    #width, height = img.size   # Get dimensions
    #left = (width - new_width)/2
    #top = (height - new_height)/2
    #right = (width + new_width)/2
    #bottom = (height + new_height)/2
    #img = img.crop((left, top, right, bottom))

    # preprocess by cropping to shorter side and then resize
    short_side = min(img.size)
    left = int((img.size[0] - short_side) / 2)
    right = left + short_side
    top = int((img.size[1] - short_side) / 2)
    bottom = top + short_side
    img = img.crop((left, top, right, bottom))
    img = img.resize((224, 224), Image.ANTIALIAS)

    # convert to numpy.ndarray
    sample = np.asarray(img)  
    # swap axes to make image from (224, 224, 3) to (3, 224, 224)
    sample = np.swapaxes(sample, 0, 2)
    sample = np.swapaxes(sample, 1, 2)
    sample = sample[np.newaxis, :] 
    print sample.shape

    # sub mean? 
    normed_img = sample - mean_rgb
    normed_img = normed_img.reshape((1, 3, 224, 224))

    mod.forward(Batch([mx.nd.array(normed_img)]), is_train=False)
    prob = mod.get_outputs()[0] 
    #prob = prob.asnumpy()[0]
    #pred = np.argsort(prob)[::-1]
    # .asnumpy() seems to fail of large arrays.
    pred = mx.ndarray.argsort(prob[0])
    pred = pred.asnumpy()[::-1]
    #print "PRED", pred
    idx = pred[0]
    idx = int(idx)
    lat, lng = grids[idx] #top result
    # lat, lng
    return lat, lng

def lambda_handler(event, context):

    #url = 'http://www.japantimes.co.jp/wp-content/uploads/2016/03/n-tower-e-20160302.jpg'
    url = None 
    data_url = None

    try:
        # API Gateway GET method
        print "Request Method:", event['httpMethod']
        if event['httpMethod'] == 'GET':
            url = event['queryStringParameters']['url']
        #API Gateway POST method
        elif event['httpMethod'] == 'POST':
            data = json.loads(event['body'])
            if data.has_key('dataurl'):
                data_url = data['dataurl']
            else:
                url = data['url']
            
    except KeyError:
        # direct invocation
        url = event['url']

    print "URL:" , url
    lat, lng = predict(url, data_url)
    latlng = "%s, %s" % (lat,lng)
    loc = geolocator.reverse(latlng)
    print "LOC:" , loc 
    
    out = {
            "headers": {
                "content-type": "application/json",
                "Access-Control-Allow-Origin": "*"
                },
            "body": '{"address": "%s", "latlng": "%s"}' % (loc[0], loc[1]),  
            "statusCode": 200
          }
    return out
# Out:
# just exit, we are not in a lambda function
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2889: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Package code and upload 

# refer for more info: http://ipython.readthedocs.io/en/stable/interactive/reference.html?highlight=input%20caching

content = _ih[-2] # Get the input from the previous cell execution 
fname = "lambda_function.py"

with open(fname, 'w') as f:
    f.write(content)

# %%
# NOTE: Pre-requisities (AWS CLI) and appropriate config credentials 
code_zip_name = 'mxnet_lambda_code.zip'

# Create a zip file with all of MXNet dependencies (-Fsr : Only sync updated files)
# !zip -9r -FSr $code_zip_name * -x *.zip
# Out:
# 	zip warning: name not matched: lib64/python2.7/linecache.py
# 	zip warning: name not matched: lib64/python2.7/posixpath.py
# 	zip warning: name not matched: lib64/python2.7/abc.py
# 	zip warning: name not matched: lib64/python2.7/fnmatch.py
# 	zip warning: name not matched: lib64/python2.7/locale.py
# 	zip warning: name not matched: lib64/python2.7/sre.py
# 	zip warning: name not matched: lib64/python2.7/genericpath.py
# 	zip warning: name not matched: lib64/python2.7/sre_constants.py
# 	zip warning: name not matched: lib64/python2.7/types.py
# 	zip warning: name not matched: lib64/python2.7/lib-dynload
# 	zip warning: name not matched: lib64/python2.7/ntpath.py
# 	zip warning: name not matched: lib64/python2.7/copy_reg.py
# 	zip warning: name not matched: lib64/python2.7/sre_parse.py
# 	zip warning: name not matched: lib64/python2.7/warnings.py
# 	zip warning: name not matched: lib64/python2.7/_abcoll.py
# 	zip warning: name not matched: lib64/python2.7/stat.py
# 	zip warning: name not matched: lib64/python2.7/codecs.py
# 	zip warning: name not matched: lib64/python2.7/UserDict.py
# 	zip warning: name not matched: lib64/python2.7/re.py
# 	zip warning: name not matched: lib64/python2.7/config
# 	zip warning: name not matched: lib64/python2.7/sre_compile.py
# 	zip warning: name not matched: lib64/python2.7/os.py
# 	zip warning: name not matched: lib64/python2.7/encodings
# 	zip warning: name not matched: lib64/python2.7/_weakrefset.py
#   adding: PIL/ (stored 0%)
#   adding: PIL/FpxImagePlugin.py (deflated 64%)
#   adding: PIL/XpmImagePlugin.py (deflated 61%)
#   adding: PIL/PdfImagePlugin.pyo (deflated 51%)
#   adding: PIL/PpmImagePlugin.pyo (deflated 53%)
#   adding: PIL/PalmImagePlugin.pyo (deflated 69%)
#   adding: PIL/BmpImagePlugin.py (deflated 68%)
#   adding: PIL/ImageQt.pyo (deflated 47%)
#   adding: PIL/GribStubImagePlugin.py (deflated 57%)
#   adding: PIL/BdfFontFile.pyo (deflated 48%)
#   adding: PIL/__init__.py (deflated 17%)
#   adding: PIL/ImImagePlugin.pyo (deflated 55%)
#   adding: PIL/IcoImagePlugin.pyo (deflated 57%)
#   adding: PIL/ImageTransform.py (deflated 59%)
#   adding: PIL/PcxImagePlugin.py (deflated 61%)
#   adding: PIL/BufrStubImagePlugin.pyo (deflated 59%)
#   adding: PIL/ImageWin.pyo (deflated 71%)
#   adding: PIL/ImageDraw.py (deflated 75%)
#   adding: PIL/WmfImagePlugin.py (deflated 64%)
#   adding: PIL/ImagePalette.pyo (deflated 62%)
#   adding: PIL/DcxImagePlugin.py (deflated 52%)
#   adding: PIL/ImageTransform.pyo (deflated 69%)
#   adding: PIL/SunImagePlugin.pyo (deflated 55%)
#   adding: PIL/ImageOps.py (deflated 69%)
#   adding: PIL/IcnsImagePlugin.py (deflated 64%)
#   adding: PIL/ImageStat.py (deflated 68%)
#   adding: PIL/ImageGrab.py (deflated 51%)
#   adding: PIL/PSDraw.py (deflated 64%)
#   adding: PIL/PcdImagePlugin.pyo (deflated 49%)
#   adding: PIL/Hdf5StubImagePlugin.py (deflated 58%)
#   adding: PIL/ImageDraw2.pyo (deflated 71%)
#   adding: PIL/TiffTags.pyo (deflated 51%)
#   adding: PIL/GifImagePlugin.py (deflated 70%)
#   adding: PIL/ImageMode.pyo (deflated 54%)
#   adding: PIL/_imagingmath.so (deflated 68%)
#   adding: PIL/MspImagePlugin.py (deflated 55%)
#   adding: PIL/PcdImagePlugin.py (deflated 53%)
#   adding: PIL/ImageColor.py (deflated 66%)
#   adding: PIL/WmfImagePlugin.pyo (deflated 61%)
#   adding: PIL/FpxImagePlugin.pyo (deflated 52%)
#   adding: PIL/BmpImagePlugin.pyo (deflated 58%)
#   adding: PIL/ImageFont.pyo (deflated 61%)
#   adding: PIL/XVThumbImagePlugin.py (deflated 51%)
#   adding: PIL/FitsStubImagePlugin.py (deflated 57%)
#   adding: PIL/_imaging.so (deflated 57%)
#   adding: PIL/IptcImagePlugin.py (deflated 67%)
#   adding: PIL/Image.pyo (deflated 62%)
#   adding: PIL/ImageOps.pyo (deflated 58%)
#   adding: PIL/ContainerIO.py (deflated 64%)
#   adding: PIL/ImageMath.py (deflated 74%)
#   adding: PIL/IcoImagePlugin.py (deflated 59%)
#   adding: PIL/IptcImagePlugin.pyo (deflated 57%)
#   adding: PIL/FontFile.py (deflated 63%)
#   adding: PIL/MicImagePlugin.pyo (deflated 52%)
#   adding: PIL/ExifTags.py (deflated 64%)
#   adding: PIL/PcfFontFile.py (deflated 70%)
#   adding: PIL/ContainerIO.pyo (deflated 64%)
#   adding: PIL/ImagePath.pyo (deflated 68%)
#   adding: PIL/SgiImagePlugin.pyo (deflated 58%)
#   adding: PIL/GbrImagePlugin.pyo (deflated 56%)
#   adding: PIL/GifImagePlugin.pyo (deflated 56%)
#   adding: PIL/TarIO.py (deflated 50%)
#   adding: PIL/GdImageFile.py (deflated 50%)
#   adding: PIL/ImageQt.py (deflated 58%)
#   adding: PIL/McIdasImagePlugin.py (deflated 53%)
#   adding: PIL/EpsImagePlugin.py (deflated 68%)
#   adding: PIL/FliImagePlugin.pyo (deflated 59%)
#   adding: PIL/PixarImagePlugin.pyo (deflated 55%)
#   adding: PIL/GbrImagePlugin.py (deflated 57%)
#   adding: PIL/JpegImagePlugin.pyo (deflated 61%)
#   adding: PIL/ImtImagePlugin.py (deflated 58%)
#   adding: PIL/OleFileIO.py (deflated 67%)
#   adding: PIL/DcxImagePlugin.pyo (deflated 55%)
#   adding: PIL/GimpPaletteFile.py (deflated 53%)
#   adding: PIL/SunImagePlugin.py (deflated 56%)
#   adding: PIL/Image.py (deflated 72%)
#   adding: PIL/PsdImagePlugin.pyo (deflated 57%)
#   adding: PIL/ImageColor.pyo (deflated 55%)
#   adding: PIL/ImageMode.py (deflated 53%)
#   adding: PIL/ImageEnhance.pyo (deflated 69%)
#   adding: PIL/CurImagePlugin.py (deflated 60%)
#   adding: PIL/ExifTags.pyo (deflated 51%)
#   adding: PIL/ImageSequence.py (deflated 45%)
#   adding: PIL/XbmImagePlugin.pyo (deflated 54%)
#   adding: PIL/PaletteFile.pyo (deflated 52%)
#   adding: PIL/McIdasImagePlugin.pyo (deflated 57%)
#   adding: PIL/ImageMath.pyo (deflated 77%)
#   adding: PIL/ImageFont.py (deflated 63%)
#   adding: PIL/ImageGrab.pyo (deflated 45%)
#   adding: PIL/PsdImagePlugin.py (deflated 68%)
#   adding: PIL/ImageFileIO.pyo (deflated 46%)
#   adding: PIL/ImagePalette.py (deflated 70%)
#   adding: PIL/MpegImagePlugin.py (deflated 61%)
#   adding: PIL/PdfImagePlugin.py (deflated 65%)
#   adding: PIL/EpsImagePlugin.pyo (deflated 56%)
#   adding: PIL/PpmImagePlugin.py (deflated 65%)
#   adding: PIL/XpmImagePlugin.pyo (deflated 50%)
#   adding: PIL/TgaImagePlugin.pyo (deflated 56%)
#   adding: PIL/TgaImagePlugin.py (deflated 64%)
#   adding: PIL/ImtImagePlugin.pyo (deflated 47%)
#   adding: PIL/PIL-1.1.6.egg-info (deflated 57%)
#   adding: PIL/ImageDraw2.py (deflated 70%)
#   adding: PIL/BufrStubImagePlugin.py (deflated 57%)
#   adding: PIL/SgiImagePlugin.py (deflated 60%)
#   adding: PIL/PSDraw.pyo (deflated 61%)
#   adding: PIL/ImImagePlugin.py (deflated 69%)
#   adding: PIL/XbmImagePlugin.py (deflated 55%)
#   adding: PIL/FliImagePlugin.py (deflated 62%)
#   adding: PIL/IcnsImagePlugin.pyo (deflated 56%)
#   adding: PIL/PngImagePlugin.pyo (deflated 65%)
#   adding: PIL/OleFileIO.pyo (deflated 58%)
#   adding: PIL/ImageStat.pyo (deflated 63%)
#   adding: PIL/ImageFileIO.py (deflated 45%)
#   adding: PIL/FontFile.pyo (deflated 53%)
#   adding: PIL/ImageWin.py (deflated 68%)
#   adding: PIL/PalmImagePlugin.py (deflated 75%)
#   adding: PIL/ImageFilter.py (deflated 71%)
#   adding: PIL/ImageChops.pyo (deflated 76%)
#   adding: PIL/Hdf5StubImagePlugin.pyo (deflated 59%)
#   adding: PIL/__init__.pyo (deflated 23%)
#   adding: PIL/PcxImagePlugin.pyo (deflated 55%)
#   adding: PIL/ImageGL.py (deflated 40%)
#   adding: PIL/MpegImagePlugin.pyo (deflated 61%)
#   adding: PIL/_imagingft.so (deflated 64%)
#   adding: PIL/BdfFontFile.py (deflated 60%)
#   adding: PIL/ImageFilter.pyo (deflated 78%)
#   adding: PIL/JpegImagePlugin.py (deflated 69%)
#   adding: PIL/TiffImagePlugin.py (deflated 71%)
#   adding: PIL/GimpGradientFile.pyo (deflated 58%)
#   adding: PIL/MicImagePlugin.py (deflated 59%)
#   adding: PIL/GdImageFile.pyo (deflated 51%)
#   adding: PIL/ImageFile.py (deflated 71%)
#   adding: PIL/PixarImagePlugin.py (deflated 50%)
#   adding: PIL/FitsStubImagePlugin.pyo (deflated 59%)
#   adding: PIL/WalImageFile.pyo (deflated 36%)
#   adding: PIL/GimpPaletteFile.pyo (deflated 53%)
#   adding: PIL/ImageSequence.pyo (deflated 51%)
#   adding: PIL/ImageEnhance.py (deflated 64%)
#   adding: PIL/TiffImagePlugin.pyo (deflated 61%)
#   adding: PIL/CurImagePlugin.pyo (deflated 56%)
#   adding: PIL/TarIO.pyo (deflated 45%)
#   adding: PIL/ImagePath.py (deflated 52%)
#   adding: PIL/ImageFile.pyo (deflated 60%)
#   adding: PIL/PngImagePlugin.py (deflated 69%)
#   adding: PIL/ImageGL.pyo (deflated 40%)
#   adding: PIL/PcfFontFile.pyo (deflated 63%)
#   adding: PIL/MspImagePlugin.pyo (deflated 55%)
#   adding: PIL/TiffTags.py (deflated 60%)
#   adding: PIL/WalImageFile.py (deflated 62%)
#   adding: PIL/GribStubImagePlugin.pyo (deflated 58%)
#   adding: PIL/ImageChops.py (deflated 74%)
#   adding: PIL/GimpGradientFile.py (deflated 63%)
#   adding: PIL/PaletteFile.py (deflated 51%)
#   adding: PIL/XVThumbImagePlugin.pyo (deflated 47%)
#   adding: PIL/ArgImagePlugin.py (deflated 76%)
#   adding: PIL/ArgImagePlugin.pyo (deflated 68%)
#   adding: PIL/ImageDraw.pyo (deflated 67%)
#   adding: bin/ (stored 0%)
#   adding: bin/easy_install-2.7 (deflated 24%)
#   adding: bin/activate.csh (deflated 53%)
#   adding: bin/rstpep2html.py (deflated 39%)
#   adding: bin/explode.py (deflated 58%)
#   adding: bin/player.py (deflated 65%)
#   adding: bin/rst2html.py (deflated 36%)
#   adding: bin/rst2xml.py (deflated 37%)
#   adding: bin/pilfile.py (deflated 58%)
#   adding: bin/enhancer.py (deflated 57%)
#   adding: bin/thresholder.py (deflated 56%)
#   adding: bin/painter.py (deflated 59%)
#   adding: bin/rst2latex.py (deflated 42%)
#   adding: bin/rst2odt_prepstyles.py (deflated 50%)
#   adding: bin/pildriver.py (deflated 76%)
#   adding: bin/rst2pseudoxml.py (deflated 38%)
#   adding: bin/python (deflated 63%)
#   adding: bin/pilfont.py (deflated 50%)
#   adding: bin/activate (deflated 64%)
#   adding: bin/gifmaker.py (deflated 39%)
#   adding: bin/pilconvert.py (deflated 60%)
#   adding: bin/activate.fish (deflated 65%)
#   adding: bin/rst2s5.py (deflated 37%)
#   adding: bin/django-admin.py (deflated 18%)
#   adding: bin/createfontdatachunk.py (deflated 49%)
#   adding: bin/easy_install (deflated 24%)
#   adding: bin/rst2html5.py (deflated 42%)
#   adding: bin/rst2xetex.py (deflated 43%)
#   adding: bin/python2 (deflated 63%)
#   adding: bin/pip2.7 (deflated 25%)
#   adding: bin/pilprint.py (deflated 59%)
#   adding: bin/jp.py (deflated 64%)
#   adding: bin/django-admin (deflated 29%)
#   adding: bin/pip (deflated 25%)
#   adding: bin/activate_this.py (deflated 54%)
#   adding: bin/rst2odt.py (deflated 42%)
#   adding: bin/viewer.py (deflated 54%)
#   adding: bin/pip2 (deflated 25%)
#   adding: bin/python2.7 (deflated 63%)
#   adding: bin/rst2man.py (deflated 41%)
#   adding: concurrent/ (stored 0%)
#   adding: concurrent/__init__.py (deflated 24%)
#   adding: concurrent/__init__.pyc (deflated 25%)
#   adding: concurrent/futures/ (stored 0%)
#   adding: concurrent/futures/__init__.py (deflated 59%)
#   adding: concurrent/futures/process.pyc (deflated 62%)
#   adding: concurrent/futures/__init__.pyc (deflated 37%)
#   adding: concurrent/futures/_base.pyc (deflated 70%)
#   adding: concurrent/futures/_base.py (deflated 78%)
#   adding: concurrent/futures/process.py (deflated 72%)
#   adding: concurrent/futures/thread.py (deflated 63%)
#   adding: concurrent/futures/thread.pyc (deflated 54%)
#   adding: dateutil/ (stored 0%)
#   adding: dateutil/__init__.py (deflated 25%)
#   adding: dateutil/__init__.pyc (deflated 27%)
#   adding: dateutil/tzwin.py (deflated 73%)
#   adding: dateutil/relativedelta.py (deflated 77%)
#   adding: dateutil/tz.pyo (deflated 66%)
#   adding: dateutil/easter.py (deflated 52%)
#   adding: dateutil/easter.pyo (deflated 45%)
#   adding: dateutil/relativedelta.pyc (deflated 60%)
#   adding: dateutil/tzwin.pyc (deflated 57%)
#   adding: dateutil/tz.py (deflated 77%)
#   adding: dateutil/rrule.py (deflated 81%)
#   adding: dateutil/parser.pyc (deflated 61%)
#   adding: dateutil/zoneinfo/ (stored 0%)
#   adding: dateutil/zoneinfo/__init__.py (deflated 61%)
#   adding: dateutil/zoneinfo/__init__.pyo (deflated 52%)
#   adding: dateutil/tz.pyc (deflated 63%)
#   adding: dateutil/relativedelta.pyo (deflated 62%)
#   adding: dateutil/parser.pyo (deflated 63%)
#   adding: dateutil/parser.py (deflated 80%)
#   adding: dateutil/tzwin.pyo (deflated 60%)
#   adding: dateutil/__init__.pyo (deflated 28%)
#   adding: dateutil/rrule.pyo (deflated 61%)
#   adding: event.json (deflated 17%)
#   adding: geolocation_lambda_sam.ipynb (deflated 74%)
#   adding: geopy/ (stored 0%)
#   adding: geopy/units.py (deflated 80%)
#   adding: geopy/__init__.py (deflated 43%)
#   adding: geopy/compat.py (deflated 72%)
#   adding: geopy/format.py (deflated 68%)
#   adding: geopy/util.py (deflated 66%)
#   adding: geopy/distance.py (deflated 75%)
#   adding: geopy/exc.py (deflated 64%)
#   adding: geopy/point.py (deflated 72%)
#   adding: geopy/geocoders/ (stored 0%)
#   adding: geopy/geocoders/__init__.py (deflated 63%)
#   adding: geopy/geocoders/yandex.py (deflated 69%)
#   adding: geopy/geocoders/geocodefarm.py (deflated 69%)
#   adding: geopy/geocoders/photon.py (deflated 73%)
#   adding: geopy/geocoders/baidu.py (deflated 71%)
#   adding: geopy/geocoders/placefinder.py (deflated 69%)
#   adding: geopy/geocoders/what3words.py (deflated 74%)
#   adding: geopy/geocoders/opencage.py (deflated 68%)
#   adding: geopy/geocoders/arcgis.py (deflated 71%)
#   adding: geopy/geocoders/smartystreets.py (deflated 64%)
#   adding: geopy/geocoders/geonames.py (deflated 70%)
#   adding: geopy/geocoders/dot_us.py (deflated 66%)
#   adding: geopy/geocoders/osm.py (deflated 71%)
#   adding: geopy/geocoders/databc.py (deflated 65%)
#   adding: geopy/geocoders/openmapquest.py (deflated 63%)
#   adding: geopy/geocoders/googlev3.py (deflated 71%)
#   adding: geopy/geocoders/navidata.py (deflated 69%)
#   adding: geopy/geocoders/bing.py (deflated 70%)
#   adding: geopy/geocoders/ignfrance.py (deflated 74%)
#   adding: geopy/geocoders/base.py (deflated 71%)
#   adding: geopy/location.py (deflated 70%)
#   adding: grids.txt (deflated 53%)
#   adding: include/ (stored 0%)
#   adding: include/python2.7/ (stored 0%)
#   adding: include/python2.7/dtoa.h (deflated 41%)
#   adding: include/python2.7/node.h (deflated 53%)
#   adding: include/python2.7/object.h (deflated 70%)
#   adding: include/python2.7/bytes_methods.h (deflated 73%)
#   adding: include/python2.7/pymacconfig.h (deflated 66%)
#   adding: include/python2.7/errcode.h (deflated 50%)
#   adding: include/python2.7/methodobject.h (deflated 62%)
#   adding: include/python2.7/cellobject.h (deflated 52%)
#   adding: include/python2.7/boolobject.h (deflated 51%)
#   adding: include/python2.7/longobject.h (deflated 65%)
#   adding: include/python2.7/parsetok.h (deflated 71%)
#   adding: include/python2.7/pystate.h (deflated 64%)
#   adding: include/python2.7/pycapsule.h (deflated 63%)
#   adding: include/python2.7/abstract.h (deflated 80%)
#   adding: include/python2.7/sysmodule.h (deflated 62%)
#   adding: include/python2.7/unicodeobject.h (deflated 80%)
#   adding: include/python2.7/datetime.h (deflated 75%)
#   adding: include/python2.7/grammar.h (deflated 61%)
#   adding: include/python2.7/listobject.h (deflated 60%)
#   adding: include/python2.7/opcode.h (deflated 64%)
#   adding: include/python2.7/objimpl.h (deflated 68%)
#   adding: include/python2.7/cobject.h (deflated 62%)
#   adding: include/python2.7/descrobject.h (deflated 72%)
#   adding: include/python2.7/import.h (deflated 68%)
#   adding: include/python2.7/stringobject.h (deflated 71%)
#   adding: include/python2.7/eval.h (deflated 55%)
#   adding: include/python2.7/graminit.h (deflated 68%)
#   adding: include/python2.7/longintrepr.h (deflated 60%)
#   adding: include/python2.7/patchlevel.h (deflated 53%)
#   adding: include/python2.7/codecs.h (deflated 72%)
#   adding: include/python2.7/pystrcmp.h (deflated 55%)
#   adding: include/python2.7/pgenheaders.h (deflated 62%)
#   adding: include/python2.7/floatobject.h (deflated 60%)
#   adding: include/python2.7/setobject.h (deflated 65%)
#   adding: include/python2.7/bufferobject.h (deflated 66%)
#   adding: include/python2.7/warnings.h (deflated 53%)
#   adding: include/python2.7/osdefs.h (deflated 57%)
#   adding: include/python2.7/cStringIO.h (deflated 59%)
#   adding: include/python2.7/bytearrayobject.h (deflated 59%)
#   adding: include/python2.7/pyerrors.h (deflated 79%)
#   adding: include/python2.7/metagrammar.h (deflated 45%)
#   adding: include/python2.7/ast.h (deflated 30%)
#   adding: include/python2.7/Python.h (deflated 62%)
#   adding: include/python2.7/dictobject.h (deflated 67%)
#   adding: include/python2.7/pystrtod.h (deflated 62%)
#   adding: include/python2.7/complexobject.h (deflated 66%)
#   adding: include/python2.7/ceval.h (deflated 68%)
#   adding: include/python2.7/pyconfig.h (deflated 30%)
#   adding: include/python2.7/compile.h (deflated 52%)
#   adding: include/python2.7/py_curses.h (deflated 64%)
#   adding: include/python2.7/Python-ast.h (deflated 86%)
#   adding: include/python2.7/pygetopt.h (deflated 46%)
#   adding: include/python2.7/pyexpat.h (deflated 66%)
#   adding: include/python2.7/token.h (deflated 58%)
#   adding: include/python2.7/bitset.h (deflated 55%)
#   adding: include/python2.7/funcobject.h (deflated 66%)
#   adding: include/python2.7/pyarena.h (deflated 57%)
#   adding: include/python2.7/marshal.h (deflated 62%)
#   adding: include/python2.7/pyfpe.h (deflated 60%)
#   adding: include/python2.7/symtable.h (deflated 63%)
#   adding: include/python2.7/frameobject.h (deflated 58%)
#   adding: include/python2.7/asdl.h (deflated 53%)
#   adding: include/python2.7/moduleobject.h (deflated 56%)
#   adding: include/python2.7/iterobject.h (deflated 54%)
#   adding: include/python2.7/classobject.h (deflated 66%)
#   adding: include/python2.7/weakrefobject.h (deflated 63%)
#   adding: include/python2.7/code.h (deflated 57%)
#   adding: include/python2.7/structseq.h (deflated 56%)
#   adding: include/python2.7/bytesobject.h (deflated 74%)
#   adding: include/python2.7/pythread.h (deflated 66%)
#   adding: include/python2.7/structmember.h (deflated 60%)
#   adding: include/python2.7/tupleobject.h (deflated 57%)
#   adding: include/python2.7/modsupport.h (deflated 62%)
#   adding: include/python2.7/genobject.h (deflated 50%)
#   adding: include/python2.7/rangeobject.h (deflated 42%)
#   adding: include/python2.7/pymath.h (deflated 62%)
#   adding: include/python2.7/sliceobject.h (deflated 59%)
#   adding: include/python2.7/ucnhash.h (deflated 48%)
#   adding: include/python2.7/pgen.h (deflated 39%)
#   adding: include/python2.7/traceback.h (deflated 52%)
#   adding: include/python2.7/pyport.h (deflated 69%)
#   adding: include/python2.7/intrcheck.h (deflated 44%)
#   adding: include/python2.7/fileobject.h (deflated 61%)
#   adding: include/python2.7/memoryobject.h (deflated 58%)
#   adding: include/python2.7/intobject.h (deflated 55%)
#   adding: include/python2.7/pydebug.h (deflated 56%)
#   adding: include/python2.7/pymem.h (deflated 59%)
#   adding: include/python2.7/enumobject.h (deflated 40%)
#   adding: include/python2.7/pyconfig-64.h (deflated 78%)
#   adding: include/python2.7/pythonrun.h (deflated 75%)
#   adding: include/python2.7/timefuncs.h (deflated 43%)
#   adding: include/python2.7/pymactoolbox.h (deflated 76%)
#   adding: include/python2.7/pyctype.h (deflated 66%)
#   adding: jmespath/ (stored 0%)
#   adding: jmespath/__init__.py (deflated 48%)
#   adding: jmespath/compat.py (deflated 68%)
#   adding: jmespath/visitor.pyc (deflated 67%)
#   adding: jmespath/__init__.pyc (deflated 47%)
#   adding: jmespath/exceptions.pyc (deflated 67%)
#   adding: jmespath/visitor.pyo (deflated 71%)
#   adding: jmespath/exceptions.pyo (deflated 71%)
#   adding: jmespath/ast.pyc (deflated 76%)
#   adding: jmespath/exceptions.py (deflated 76%)
#   adding: jmespath/compat.pyc (deflated 58%)
#   adding: jmespath/visitor.py (deflated 76%)
#   adding: jmespath/lexer.pyo (deflated 57%)
#   adding: jmespath/parser.pyc (deflated 65%)
#   adding: jmespath/functions.pyo (deflated 68%)
#   adding: jmespath/parser.pyo (deflated 68%)
#   adding: jmespath/compat.pyo (deflated 62%)
#   adding: jmespath/parser.py (deflated 79%)
#   adding: jmespath/lexer.py (deflated 78%)
#   adding: jmespath/__init__.pyo (deflated 50%)
#   adding: jmespath/lexer.pyc (deflated 55%)
#   adding: jmespath/functions.pyc (deflated 65%)
#   adding: jmespath/functions.py (deflated 76%)
#   adding: jmespath/ast.py (deflated 76%)
#   adding: jmespath/ast.pyo (deflated 79%)
#   adding: lambda_code.py (deflated 64%)
#   adding: lambda_function.py (deflated 60%)
#   adding: lib/ (stored 0%)
#   adding: lib/liblapack.so.3.0 (deflated 55%)
#   adding: lib/libptcblas.so.3 (deflated 70%)
#   adding: lib/liblapack.so.3 (deflated 55%)
#   adding: lib/libcblas.so.3.0 (deflated 70%)
#   adding: lib/libquadmath.so.0 (deflated 43%)
#   adding: lib/libgfortran.so.3 (deflated 71%)
#   adding: lib/libatlas.so.3.0 (deflated 81%)
#   adding: lib/libptf77blas.so.3 (deflated 76%)
#   adding: lib/libatlas.so.3 (deflated 81%)
#   adding: lib/libclapack.so.3 (deflated 68%)
#   adding: lib/libptcblas.so.3.0 (deflated 70%)
#   adding: lib/libptf77blas.so.3.0 (deflated 76%)
#   adding: lib/libf77blas.so.3.0 (deflated 76%)
#   adding: lib/libcblas.so.3 (deflated 70%)
#   adding: lib/libf77blas.so.3 (deflated 76%)
#   adding: lib/libclapack.so.3.0 (deflated 68%)
#   adding: lib/libopenblas.so.0 (deflated 74%)
#   adding: lib64/ (stored 0%)
#   adding: lib64/python2.7/ (stored 0%)
#   adding: lib64/python2.7/dist-packages/ (stored 0%)
#   adding: lib64/python2.7/no-global-site-packages.txt (stored 0%)
#   adding: lib64/python2.7/orig-prefix.txt (stored 0%)
#   adding: lib64/python2.7/distutils/ (stored 0%)
#   adding: lib64/python2.7/distutils/__init__.py (deflated 68%)
#   adding: lib64/python2.7/distutils/distutils.cfg (deflated 29%)
#   adding: lib64/python2.7/site-packages/ (stored 0%)
#   adding: lib64/python2.7/site.py (deflated 73%)
#   adding: mxnet/ (stored 0%)
#   adding: mxnet/rnn/ (stored 0%)
#   adding: mxnet/rnn/__init__.py (deflated 45%)
#   adding: mxnet/rnn/rnn.py (deflated 66%)
#   adding: mxnet/rnn/io.py (deflated 68%)
#   adding: mxnet/rnn/rnn_cell.py (deflated 83%)
#   adding: mxnet/random.py (deflated 53%)
#   adding: mxnet/_ndarray_internal.py (stored 0%)
#   adding: mxnet/__init__.py (deflated 59%)
#   adding: mxnet/model.py (deflated 77%)
#   adding: mxnet/contrib/ (stored 0%)
#   adding: mxnet/contrib/__init__.py (deflated 46%)
#   adding: mxnet/contrib/ndarray.py (deflated 42%)
#   adding: mxnet/contrib/autograd.py (deflated 69%)
#   adding: mxnet/contrib/symbol.py (deflated 42%)
#   adding: mxnet/contrib/tensorboard.py (deflated 57%)
#   adding: mxnet/visualization.py (deflated 72%)
#   adding: mxnet/executor_manager.py (deflated 73%)
#   adding: mxnet/context.py (deflated 67%)
#   adding: mxnet/_ctypes/ (stored 0%)
#   adding: mxnet/_ctypes/__init__.py (deflated 42%)
#   adding: mxnet/_ctypes/ndarray.py (deflated 70%)
#   adding: mxnet/_ctypes/symbol.py (deflated 65%)
#   adding: mxnet/_ctypes/common.py (deflated 59%)
#   adding: mxnet/ndarray.py (deflated 82%)
#   adding: mxnet/metric.py (deflated 82%)
#   adding: mxnet/ndarray_doc.py (deflated 62%)
#   adding: mxnet/profiler.py (deflated 53%)
#   adding: mxnet/initializer.py (deflated 74%)
#   adding: mxnet/kvstore_server.py (deflated 57%)
#   adding: mxnet/test_utils.py (deflated 77%)
#   adding: mxnet/ndarray/ (stored 0%)
#   adding: mxnet/ndarray/random.py (deflated 78%)
#   adding: mxnet/ndarray/__init__.py (deflated 48%)
#   adding: mxnet/ndarray/ndarray.py (deflated 84%)
#   adding: mxnet/ndarray/_internal.py (deflated 58%)
#   adding: mxnet/ndarray/contrib.py (deflated 42%)
#   adding: mxnet/ndarray/gen_op.py (deflated 83%)
#   adding: mxnet/ndarray/gen_linalg.py (deflated 82%)
#   adding: mxnet/ndarray/gen_contrib.py (deflated 80%)
#   adding: mxnet/ndarray/gen_sparse.py (deflated 85%)
#   adding: mxnet/ndarray/op.py (deflated 44%)
#   adding: mxnet/ndarray/register.py (deflated 69%)
#   adding: mxnet/ndarray/linalg.py (deflated 42%)
#   adding: mxnet/ndarray/utils.py (deflated 72%)
#   adding: mxnet/ndarray/sparse.py (deflated 81%)
#   adding: mxnet/ndarray/gen__internal.py (deflated 92%)
#   adding: mxnet/_symbol_internal.py (stored 0%)
#   adding: mxnet/recordio.py (deflated 73%)
#   adding: mxnet/kvstore.py (deflated 75%)
#   adding: mxnet/rtc.py (deflated 68%)
#   adding: mxnet/lr_scheduler.py (deflated 68%)
#   adding: mxnet/callback.py (deflated 68%)
#   adding: mxnet/symbol_doc.py (deflated 66%)
#   adding: mxnet/operator.py (deflated 85%)
#   adding: mxnet/io.py (deflated 75%)
#   adding: mxnet/_cy3/ (stored 0%)
#   adding: mxnet/_cy3/__init__.py (deflated 42%)
#   adding: mxnet/optimizer.py (deflated 80%)
#   adding: mxnet/monitor.py (deflated 64%)
#   adding: mxnet/autograd.py (deflated 74%)
#   adding: mxnet/image.py (deflated 72%)
#   adding: mxnet/module/ (stored 0%)
#   adding: mxnet/module/__init__.py (deflated 47%)
#   adding: mxnet/module/module.py (deflated 78%)
#   adding: mxnet/module/executor_group.py (deflated 76%)
#   adding: mxnet/module/base_module.py (deflated 76%)
#   adding: mxnet/module/sequential_module.py (deflated 73%)
#   adding: mxnet/module/bucketing_module.py (deflated 77%)
#   adding: mxnet/module/python_module.py (deflated 72%)
#   adding: mxnet/symbol.py (deflated 80%)
#   adding: mxnet/libinfo.py (deflated 60%)
#   adding: mxnet/name.py (deflated 58%)
#   adding: mxnet/misc.py (deflated 60%)
#   adding: mxnet/symbol/ (stored 0%)
#   adding: mxnet/symbol/random.py (deflated 77%)
#   adding: mxnet/symbol/__init__.py (deflated 47%)
#   adding: mxnet/symbol/_internal.py (deflated 57%)
#   adding: mxnet/symbol/contrib.py (deflated 42%)
#   adding: mxnet/symbol/gen_op.py (deflated 82%)
#   adding: mxnet/symbol/gen_linalg.py (deflated 81%)
#   adding: mxnet/symbol/gen_contrib.py (deflated 80%)
#   adding: mxnet/symbol/gen_sparse.py (deflated 85%)
#   adding: mxnet/symbol/symbol.py (deflated 83%)
#   adding: mxnet/symbol/op.py (deflated 42%)
#   adding: mxnet/symbol/register.py (deflated 71%)
#   adding: mxnet/symbol/linalg.py (deflated 42%)
#   adding: mxnet/symbol/sparse.py (deflated 43%)
#   adding: mxnet/symbol/gen__internal.py (deflated 92%)
#   adding: mxnet/torch.py (deflated 67%)
#   adding: mxnet/gluon/ (stored 0%)
#   adding: mxnet/gluon/rnn/ (stored 0%)
#   adding: mxnet/gluon/rnn/__init__.py (deflated 42%)
#   adding: mxnet/gluon/rnn/rnn_cell.py (deflated 80%)
#   adding: mxnet/gluon/rnn/rnn_layer.py (deflated 80%)
#   adding: mxnet/gluon/__init__.py (deflated 47%)
#   adding: mxnet/gluon/nn/ (stored 0%)
#   adding: mxnet/gluon/nn/__init__.py (deflated 43%)
#   adding: mxnet/gluon/nn/basic_layers.py (deflated 73%)
#   adding: mxnet/gluon/nn/conv_layers.py (deflated 89%)
#   adding: mxnet/gluon/contrib/ (stored 0%)
#   adding: mxnet/gluon/contrib/rnn/ (stored 0%)
#   adding: mxnet/gluon/contrib/rnn/__init__.py (deflated 45%)
#   adding: mxnet/gluon/contrib/rnn/conv_rnn_cell.py (deflated 91%)
#   adding: mxnet/gluon/contrib/rnn/rnn_cell.py (deflated 70%)
#   adding: mxnet/gluon/contrib/__init__.py (deflated 42%)
#   adding: mxnet/gluon/trainer.py (deflated 70%)
#   adding: mxnet/gluon/parameter.py (deflated 74%)
#   adding: mxnet/gluon/data/ (stored 0%)
#   adding: mxnet/gluon/data/__init__.py (deflated 44%)
#   adding: mxnet/gluon/data/vision.py (deflated 72%)
#   adding: mxnet/gluon/data/dataloader.py (deflated 61%)
#   adding: mxnet/gluon/data/dataset.py (deflated 57%)
#   adding: mxnet/gluon/data/sampler.py (deflated 67%)
#   adding: mxnet/gluon/model_zoo/ (stored 0%)
#   adding: mxnet/gluon/model_zoo/__init__.py (deflated 43%)
#   adding: mxnet/gluon/model_zoo/model_store.py (deflated 54%)
#   adding: mxnet/gluon/model_zoo/vision/ (stored 0%)
#   adding: mxnet/gluon/model_zoo/vision/__init__.py (deflated 62%)
#   adding: mxnet/gluon/model_zoo/vision/vgg.py (deflated 80%)
#   adding: mxnet/gluon/model_zoo/vision/squeezenet.py (deflated 76%)
#   adding: mxnet/gluon/model_zoo/vision/resnet.py (deflated 86%)
#   adding: mxnet/gluon/model_zoo/vision/inception.py (deflated 77%)
#   adding: mxnet/gluon/model_zoo/vision/mobilenet.py (deflated 73%)
#   adding: mxnet/gluon/model_zoo/vision/alexnet.py (deflated 65%)
#   adding: mxnet/gluon/model_zoo/vision/densenet.py (deflated 74%)
#   adding: mxnet/gluon/model_zoo/custom_layers.py (deflated 60%)
#   adding: mxnet/gluon/block.py (deflated 72%)
#   adding: mxnet/gluon/loss.py (deflated 81%)
#   adding: mxnet/gluon/utils.py (deflated 63%)
#   adding: mxnet/attribute.py (deflated 58%)
#   adding: mxnet/log.py (deflated 63%)
#   adding: mxnet/_cy2/ (stored 0%)
#   adding: mxnet/_cy2/__init__.py (deflated 43%)
#   adding: mxnet/executor.py (deflated 74%)
#   adding: mxnet/notebook/ (stored 0%)
#   adding: mxnet/notebook/__init__.py (deflated 45%)
#   adding: mxnet/notebook/callback.py (deflated 74%)
#   adding: mxnet/image/ (stored 0%)
#   adding: mxnet/image/__init__.py (deflated 46%)
#   adding: mxnet/image/detection.py (deflated 76%)
#   adding: mxnet/image/image.py (deflated 77%)
#   adding: mxnet/registry.py (deflated 67%)
#   adding: mxnet/base.py (deflated 72%)
#   adding: mxnet/libmxnet.so (deflated 68%)
#   adding: mxnet-0.12.0-py2.7.egg/ (stored 0%)
#   adding: mxnet-0.12.0-py2.7.egg/EGG-INFO/ (stored 0%)
#   adding: mxnet-0.12.0-py2.7.egg/EGG-INFO/not-zip-safe (stored 0%)
#   adding: mxnet-0.12.0-py2.7.egg/EGG-INFO/top_level.txt (stored 0%)
#   adding: mxnet-0.12.0-py2.7.egg/EGG-INFO/dependency_links.txt (stored 0%)
#   adding: mxnet-0.12.0-py2.7.egg/EGG-INFO/PKG-INFO (deflated 45%)
#   adding: mxnet-0.12.0-py2.7.egg/EGG-INFO/requires.txt (stored 0%)
#   adding: mxnet-0.12.0-py2.7.egg/EGG-INFO/SOURCES.txt (deflated 76%)
#   adding: numpy/ (stored 0%)
#   adding: numpy/doc/ (stored 0%)
#   adding: numpy/doc/__init__.py (deflated 41%)
#   adding: numpy/doc/ufuncs.py (deflated 58%)
#   adding: numpy/doc/methods_vs_functions.py (deflated 41%)
#   adding: numpy/doc/creation.py (deflated 56%)
#   adding: numpy/doc/howtofind.py (deflated 31%)
#   adding: numpy/doc/indexing.py (deflated 65%)
#   adding: numpy/doc/io.py (deflated 24%)
#   adding: numpy/doc/structured_arrays.py (deflated 65%)
#   adding: numpy/doc/byteswapping.py (deflated 64%)
#   adding: numpy/doc/internals.py (deflated 60%)
#   adding: numpy/doc/misc.py (deflated 57%)
#   adding: numpy/doc/performance.py (deflated 30%)
#   adding: numpy/doc/basics.py (deflated 60%)
#   adding: numpy/doc/jargon.py (deflated 25%)
#   adding: numpy/doc/subclassing.py (deflated 69%)
#   adding: numpy/doc/broadcasting.py (deflated 62%)
#   adding: numpy/doc/constants.py (deflated 80%)
#   adding: numpy/doc/glossary.py (deflated 66%)
#   adding: numpy/add_newdocs.py (deflated 77%)
#   adding: numpy/__init__.py (deflated 58%)
#   adding: numpy/compat/ (stored 0%)
#   adding: numpy/compat/__init__.py (deflated 44%)
#   adding: numpy/compat/py3k.py (deflated 71%)
#   adding: numpy/compat/setup.py (deflated 45%)
#   adding: numpy/compat/_inspect.py (deflated 71%)
#   adding: numpy/ctypeslib.py (deflated 70%)
#   adding: numpy/tests/ (stored 0%)
#   adding: numpy/tests/test_matlib.py (deflated 71%)
#   adding: numpy/tests/test_scripts.py (deflated 60%)
#   adding: numpy/tests/test_warnings.py (deflated 64%)
#   adding: numpy/tests/test_reloading.py (deflated 65%)
#   adding: numpy/tests/test_numpy_version.py (deflated 48%)
#   adding: numpy/tests/test_ctypeslib.py (deflated 74%)
#   adding: numpy/_globals.py (deflated 54%)
#   adding: numpy/testing/ (stored 0%)
#   adding: numpy/testing/__init__.py (deflated 46%)
#   adding: numpy/testing/tests/ (stored 0%)
#   adding: numpy/testing/tests/test_doctesting.py (deflated 47%)
#   adding: numpy/testing/tests/test_utils.py (deflated 85%)
#   adding: numpy/testing/tests/test_decorators.py (deflated 78%)
#   adding: numpy/testing/nosetester.py (deflated 71%)
#   adding: numpy/testing/decorators.py (deflated 72%)
#   adding: numpy/testing/noseclasses.py (deflated 68%)
#   adding: numpy/testing/print_coercion_tables.py (deflated 72%)
#   adding: numpy/testing/setup.py (deflated 50%)
#   adding: numpy/testing/utils.py (deflated 76%)
#   adding: numpy/_import_tools.py (deflated 75%)
#   adding: numpy/fft/ (stored 0%)
#   adding: numpy/fft/info.py (deflated 63%)
#   adding: numpy/fft/__init__.py (deflated 43%)
#   adding: numpy/fft/tests/ (stored 0%)
#   adding: numpy/fft/tests/test_fftpack.py (deflated 79%)
#   adding: numpy/fft/tests/test_helper.py (deflated 76%)
#   adding: numpy/fft/helper.py (deflated 71%)
#   adding: numpy/fft/setup.py (deflated 53%)
#   adding: numpy/fft/fftpack.py (deflated 82%)
#   adding: numpy/fft/fftpack_lite.so (deflated 48%)
#   adding: numpy/.libs/ (stored 0%)
#   adding: numpy/.libs/libgfortran-ed201abd.so.3.0.0 (deflated 72%)
#   adding: numpy/.libs/libopenblasp-r0-39a31c03.2.18.so (deflated 78%)
#   adding: numpy/matlib.py (deflated 71%)
#   adding: numpy/__config__.py (deflated 63%)
#   adding: numpy/core/ (stored 0%)
#   adding: numpy/core/info.py (deflated 71%)
#   adding: numpy/core/__init__.py (deflated 59%)
#   adding: numpy/core/shape_base.py (deflated 74%)
#   adding: numpy/core/_dummy.so (deflated 66%)
#   adding: numpy/core/tests/ (stored 0%)
#   adding: numpy/core/tests/test_umath_complex.py (deflated 81%)
#   adding: numpy/core/tests/test_unicode.py (deflated 84%)
#   adding: numpy/core/tests/test_machar.py (deflated 52%)
#   adding: numpy/core/tests/test_numeric.py (deflated 83%)
#   adding: numpy/core/tests/test_function_base.py (deflated 77%)
#   adding: numpy/core/tests/test_indexerrors.py (deflated 83%)
#   adding: numpy/core/tests/test_print.py (deflated 76%)
#   adding: numpy/core/tests/test_half.py (deflated 79%)
#   adding: numpy/core/tests/test_extint128.py (deflated 77%)
#   adding: numpy/core/tests/test_umath.py (deflated 82%)
#   adding: numpy/core/tests/test_records.py (deflated 76%)
#   adding: numpy/core/tests/test_scalarmath.py (deflated 76%)
#   adding: numpy/core/tests/test_item_selection.py (deflated 68%)
#   adding: numpy/core/tests/test_multiarray.py (deflated 81%)
#   adding: numpy/core/tests/test_shape_base.py (deflated 83%)
#   adding: numpy/core/tests/test_mem_overlap.py (deflated 77%)
#   adding: numpy/core/tests/test_ufunc.py (deflated 80%)
#   adding: numpy/core/tests/test_abc.py (deflated 81%)
#   adding: numpy/core/tests/test_scalarinherit.py (deflated 57%)
#   adding: numpy/core/tests/test_api.py (deflated 79%)
#   adding: numpy/core/tests/data/ (stored 0%)
#   adding: numpy/core/tests/data/astype_copy.pkl (deflated 6%)
#   adding: numpy/core/tests/data/recarray_from_file.fits (deflated 90%)
#   adding: numpy/core/tests/test_multiarray_assignment.py (deflated 60%)
#   adding: numpy/core/tests/test_numerictypes.py (deflated 82%)
#   adding: numpy/core/tests/test_memmap.py (deflated 75%)
#   adding: numpy/core/tests/test_deprecations.py (deflated 70%)
#   adding: numpy/core/tests/test_indexing.py (deflated 76%)
#   adding: numpy/core/tests/test_nditer.py (deflated 85%)
#   adding: numpy/core/tests/test_getlimits.py (deflated 70%)
#   adding: numpy/core/tests/test_datetime.py (deflated 86%)
#   adding: numpy/core/tests/test_longdouble.py (deflated 76%)
#   adding: numpy/core/tests/test_arrayprint.py (deflated 76%)
#   adding: numpy/core/tests/test_scalarprint.py (deflated 57%)
#   adding: numpy/core/tests/test_errstate.py (deflated 68%)
#   adding: numpy/core/tests/test_regression.py (deflated 75%)
#   adding: numpy/core/tests/test_einsum.py (deflated 83%)
#   adding: numpy/core/tests/test_dtype.py (deflated 82%)
#   adding: numpy/core/tests/test_defchararray.py (deflated 84%)
#   adding: numpy/core/_methods.py (deflated 72%)
#   adding: numpy/core/memmap.py (deflated 68%)
#   adding: numpy/core/function_base.py (deflated 70%)
#   adding: numpy/core/multiarray.so (deflated 66%)
#   adding: numpy/core/setup_common.py (deflated 67%)
#   adding: numpy/core/arrayprint.py (deflated 75%)
#   adding: numpy/core/records.py (deflated 72%)
#   adding: numpy/core/_internal.py (deflated 70%)
#   adding: numpy/core/test_rational.so (deflated 60%)
#   adding: numpy/core/umath_tests.so (deflated 59%)
#   adding: numpy/core/generate_numpy_api.py (deflated 70%)
#   adding: numpy/core/numeric.py (deflated 74%)
#   adding: numpy/core/defchararray.py (deflated 83%)
#   adding: numpy/core/multiarray_tests.so (deflated 56%)
#   adding: numpy/core/setup.py (deflated 78%)
#   adding: numpy/core/fromnumeric.py (deflated 79%)
#   adding: numpy/core/include/ (stored 0%)
#   adding: numpy/core/include/numpy/ (stored 0%)
#   adding: numpy/core/include/numpy/npy_os.h (deflated 69%)
#   adding: numpy/core/include/numpy/utils.h (deflated 57%)
#   adding: numpy/core/include/numpy/npy_1_7_deprecated_api.h (deflated 68%)
#   adding: numpy/core/include/numpy/old_defines.h (deflated 79%)
#   adding: numpy/core/include/numpy/npy_cpu.h (deflated 69%)
#   adding: numpy/core/include/numpy/halffloat.h (deflated 70%)
#   adding: numpy/core/include/numpy/npy_interrupt.h (deflated 59%)
#   adding: numpy/core/include/numpy/arrayobject.h (deflated 32%)
#   adding: numpy/core/include/numpy/ufunc_api.txt (deflated 82%)
#   adding: numpy/core/include/numpy/ufuncobject.h (deflated 69%)
#   adding: numpy/core/include/numpy/noprefix.h (deflated 74%)
#   adding: numpy/core/include/numpy/__multiarray_api.h (deflated 87%)
#   adding: numpy/core/include/numpy/_numpyconfig.h (deflated 67%)
#   adding: numpy/core/include/numpy/_neighborhood_iterator_imp.h (deflated 66%)
#   adding: numpy/core/include/numpy/npy_endian.h (deflated 77%)
#   adding: numpy/core/include/numpy/ndarraytypes.h (deflated 76%)
#   adding: numpy/core/include/numpy/npy_common.h (deflated 82%)
#   adding: numpy/core/include/numpy/__ufunc_api.h (deflated 87%)
#   adding: numpy/core/include/numpy/oldnumeric.h (deflated 51%)
#   adding: numpy/core/include/numpy/multiarray_api.txt (deflated 72%)
#   adding: numpy/core/include/numpy/npy_no_deprecated_api.h (deflated 42%)
#   adding: numpy/core/include/numpy/numpyconfig.h (deflated 59%)
#   adding: numpy/core/include/numpy/npy_3kcompat.h (deflated 76%)
#   adding: numpy/core/include/numpy/ndarrayobject.h (deflated 76%)
#   adding: numpy/core/include/numpy/arrayscalars.h (deflated 80%)
#   adding: numpy/core/include/numpy/npy_math.h (deflated 81%)
#   adding: numpy/core/lib/ (stored 0%)
#   adding: numpy/core/lib/libnpymath.a (deflated 74%)
#   adding: numpy/core/lib/npy-pkg-config/ (stored 0%)
#   adding: numpy/core/lib/npy-pkg-config/mlib.ini (deflated 20%)
#   adding: numpy/core/lib/npy-pkg-config/npymath.ini (deflated 36%)
#   adding: numpy/core/einsumfunc.py (deflated 74%)
#   adding: numpy/core/struct_ufunc_test.so (deflated 61%)
#   adding: numpy/core/machar.py (deflated 73%)
#   adding: numpy/core/cversions.py (deflated 42%)
#   adding: numpy/core/umath.so (deflated 72%)
#   adding: numpy/core/numerictypes.py (deflated 73%)
#   adding: numpy/core/operand_flag_tests.so (deflated 62%)
#   adding: numpy/core/getlimits.py (deflated 74%)
#   adding: numpy/distutils/ (stored 0%)
#   adding: numpy/distutils/cpuinfo.py (deflated 81%)
#   adding: numpy/distutils/info.py (deflated 24%)
#   adding: numpy/distutils/msvccompiler.py (deflated 59%)
#   adding: numpy/distutils/exec_command.py (deflated 65%)
#   adding: numpy/distutils/extension.py (deflated 69%)
#   adding: numpy/distutils/__init__.py (deflated 47%)
#   adding: numpy/distutils/ccompiler.py (deflated 71%)
#   adding: numpy/distutils/tests/ (stored 0%)
#   adding: numpy/distutils/tests/f2py_f90_ext/ (stored 0%)
#   adding: numpy/distutils/tests/f2py_f90_ext/__init__.py (deflated 6%)
#   adding: numpy/distutils/tests/f2py_f90_ext/src/ (stored 0%)
#   adding: numpy/distutils/tests/f2py_f90_ext/src/foo_free.f90 (deflated 17%)
#   adding: numpy/distutils/tests/f2py_f90_ext/tests/ (stored 0%)
#   adding: numpy/distutils/tests/f2py_f90_ext/tests/test_foo.py (deflated 37%)
#   adding: numpy/distutils/tests/f2py_f90_ext/setup.py (deflated 56%)
#   adding: numpy/distutils/tests/f2py_f90_ext/include/ (stored 0%)
#   adding: numpy/distutils/tests/f2py_f90_ext/include/body.f90 (deflated 29%)
#   adding: numpy/distutils/tests/test_npy_pkg_config.py (deflated 74%)
#   adding: numpy/distutils/tests/test_system_info.py (deflated 72%)
#   adding: numpy/distutils/tests/test_exec_command.py (deflated 78%)
#   adding: numpy/distutils/tests/gen_ext/ (stored 0%)
#   adding: numpy/distutils/tests/gen_ext/__init__.py (deflated 6%)
#   adding: numpy/distutils/tests/gen_ext/tests/ (stored 0%)
#   adding: numpy/distutils/tests/gen_ext/tests/test_fib3.py (deflated 37%)
#   adding: numpy/distutils/tests/gen_ext/setup.py (deflated 51%)
#   adding: numpy/distutils/tests/swig_ext/ (stored 0%)
#   adding: numpy/distutils/tests/swig_ext/__init__.py (deflated 6%)
#   adding: numpy/distutils/tests/swig_ext/src/ (stored 0%)
#   adding: numpy/distutils/tests/swig_ext/src/zoo.i (deflated 19%)
#   adding: numpy/distutils/tests/swig_ext/src/example.c (deflated 32%)
#   adding: numpy/distutils/tests/swig_ext/src/example.i (deflated 49%)
#   adding: numpy/distutils/tests/swig_ext/src/zoo.h (deflated 19%)
#   adding: numpy/distutils/tests/swig_ext/src/zoo.cc (deflated 35%)
#   adding: numpy/distutils/tests/swig_ext/tests/ (stored 0%)
#   adding: numpy/distutils/tests/swig_ext/tests/test_example2.py (deflated 41%)
#   adding: numpy/distutils/tests/swig_ext/tests/test_example.py (deflated 50%)
#   adding: numpy/distutils/tests/swig_ext/setup.py (deflated 60%)
#   adding: numpy/distutils/tests/setup.py (deflated 56%)
#   adding: numpy/distutils/tests/test_misc_util.py (deflated 75%)
#   adding: numpy/distutils/tests/test_fcompiler_intel.py (deflated 67%)
#   adding: numpy/distutils/tests/f2py_ext/ (stored 0%)
#   adding: numpy/distutils/tests/f2py_ext/__init__.py (deflated 6%)
#   adding: numpy/distutils/tests/f2py_ext/src/ (stored 0%)
#   adding: numpy/distutils/tests/f2py_ext/src/fib1.f (deflated 51%)
#   adding: numpy/distutils/tests/f2py_ext/src/fib2.pyf (deflated 45%)
#   adding: numpy/distutils/tests/f2py_ext/tests/ (stored 0%)
#   adding: numpy/distutils/tests/f2py_ext/tests/test_fib2.py (deflated 37%)
#   adding: numpy/distutils/tests/f2py_ext/setup.py (deflated 46%)
#   adding: numpy/distutils/tests/test_fcompiler_gnu.py (deflated 71%)
#   adding: numpy/distutils/tests/pyrex_ext/ (stored 0%)
#   adding: numpy/distutils/tests/pyrex_ext/__init__.py (deflated 6%)
#   adding: numpy/distutils/tests/pyrex_ext/tests/ (stored 0%)
#   adding: numpy/distutils/tests/pyrex_ext/tests/test_primes.py (deflated 37%)
#   adding: numpy/distutils/tests/pyrex_ext/setup.py (deflated 48%)
#   adding: numpy/distutils/tests/pyrex_ext/primes.pyx (deflated 44%)
#   adding: numpy/distutils/compat.py (deflated 26%)
#   adding: numpy/distutils/__version__.py (deflated 25%)
#   adding: numpy/distutils/core.py (deflated 73%)
#   adding: numpy/distutils/line_endings.py (deflated 73%)
#   adding: numpy/distutils/lib2def.py (deflated 63%)
#   adding: numpy/distutils/npy_pkg_config.py (deflated 70%)
#   adding: numpy/distutils/fcompiler/ (stored 0%)
#   adding: numpy/distutils/fcompiler/__init__.py (deflated 74%)
#   adding: numpy/distutils/fcompiler/intel.py (deflated 75%)
#   adding: numpy/distutils/fcompiler/nag.py (deflated 58%)
#   adding: numpy/distutils/fcompiler/hpux.py (deflated 57%)
#   adding: numpy/distutils/fcompiler/g95.py (deflated 57%)
#   adding: numpy/distutils/fcompiler/compaq.py (deflated 66%)
#   adding: numpy/distutils/fcompiler/vast.py (deflated 57%)
#   adding: numpy/distutils/fcompiler/lahey.py (deflated 57%)
#   adding: numpy/distutils/fcompiler/sun.py (deflated 57%)
#   adding: numpy/distutils/fcompiler/pg.py (deflated 64%)
#   adding: numpy/distutils/fcompiler/ibm.py (deflated 62%)
#   adding: numpy/distutils/fcompiler/pathf95.py (deflated 56%)
#   adding: numpy/distutils/fcompiler/none.py (deflated 59%)
#   adding: numpy/distutils/fcompiler/absoft.py (deflated 68%)
#   adding: numpy/distutils/fcompiler/mips.py (deflated 60%)
#   adding: numpy/distutils/fcompiler/gnu.py (deflated 71%)
#   adding: numpy/distutils/mingw/ (stored 0%)
#   adding: numpy/distutils/mingw/gfortran_vs2003_hack.c (deflated 5%)
#   adding: numpy/distutils/__config__.py (deflated 63%)
#   adding: numpy/distutils/pathccompiler.py (deflated 61%)
#   adding: numpy/distutils/command/ (stored 0%)
#   adding: numpy/distutils/command/__init__.py (deflated 58%)
#   adding: numpy/distutils/command/bdist_rpm.py (deflated 59%)
#   adding: numpy/distutils/command/develop.py (deflated 50%)
#   adding: numpy/distutils/command/install_data.py (deflated 60%)
#   adding: numpy/distutils/command/config_compiler.py (deflated 77%)
#   adding: numpy/distutils/command/install_clib.py (deflated 62%)
#   adding: numpy/distutils/command/build.py (deflated 64%)
#   adding: numpy/distutils/command/install.py (deflated 62%)
#   adding: numpy/distutils/command/sdist.py (deflated 60%)
#   adding: numpy/distutils/command/build_src.py (deflated 79%)
#   adding: numpy/distutils/command/build_scripts.py (deflated 69%)
#   adding: numpy/distutils/command/egg_info.py (deflated 54%)
#   adding: numpy/distutils/command/install_headers.py (deflated 59%)
#   adding: numpy/distutils/command/build_ext.py (deflated 79%)
#   adding: numpy/distutils/command/build_clib.py (deflated 78%)
#   adding: numpy/distutils/command/config.py (deflated 75%)
#   adding: numpy/distutils/command/build_py.py (deflated 65%)
#   adding: numpy/distutils/command/autodist.py (deflated 68%)
#   adding: numpy/distutils/from_template.py (deflated 65%)
#   adding: numpy/distutils/system_info.py (deflated 78%)
#   adding: numpy/distutils/intelccompiler.py (deflated 76%)
#   adding: numpy/distutils/unixccompiler.py (deflated 63%)
#   adding: numpy/distutils/setup.py (deflated 53%)
#   adding: numpy/distutils/log.py (deflated 64%)
#   adding: numpy/distutils/environment.py (deflated 71%)
#   adding: numpy/distutils/misc_util.py (deflated 76%)
#   adding: numpy/distutils/conv_template.py (deflated 65%)
#   adding: numpy/distutils/mingw32ccompiler.py (deflated 69%)
#   adding: numpy/distutils/numpy_distribution.py (deflated 51%)
#   adding: numpy/distutils/msvc9compiler.py (deflated 60%)
#   adding: numpy/version.py (deflated 30%)
#   adding: numpy/linalg/ (stored 0%)
#   adding: numpy/linalg/info.py (deflated 61%)
#   adding: numpy/linalg/__init__.py (deflated 75%)
#   adding: numpy/linalg/tests/ (stored 0%)
#   adding: numpy/linalg/tests/test_linalg.py (deflated 81%)
#   adding: numpy/linalg/tests/test_deprecations.py (deflated 56%)
#   adding: numpy/linalg/tests/test_regression.py (deflated 73%)
#   adding: numpy/linalg/tests/test_build.py (deflated 56%)
#   adding: numpy/linalg/_umath_linalg.so (deflated 67%)
#   adding: numpy/linalg/lapack_lite.so (deflated 75%)
#   adding: numpy/linalg/setup.py (deflated 68%)
#   adding: numpy/linalg/linalg.py (deflated 73%)
#   adding: numpy/_distributor_init.py (deflated 37%)
#   adding: numpy/ma/ (stored 0%)
#   adding: numpy/ma/bench.py (deflated 76%)
#   adding: numpy/ma/__init__.py (deflated 51%)
#   adding: numpy/ma/tests/ (stored 0%)
#   adding: numpy/ma/tests/test_core.py (deflated 82%)
#   adding: numpy/ma/tests/test_extras.py (deflated 85%)
#   adding: numpy/ma/tests/test_old_ma.py (deflated 79%)
#   adding: numpy/ma/tests/test_deprecations.py (deflated 69%)
#   adding: numpy/ma/tests/test_mrecords.py (deflated 80%)
#   adding: numpy/ma/tests/test_subclassing.py (deflated 76%)
#   adding: numpy/ma/tests/test_regression.py (deflated 65%)
#   adding: numpy/ma/mrecords.py (deflated 73%)
#   adding: numpy/ma/core.py (deflated 78%)
#   adding: numpy/ma/testutils.py (deflated 76%)
#   adding: numpy/ma/timer_comparison.py (deflated 78%)
#   adding: numpy/ma/version.py (deflated 43%)
#   adding: numpy/ma/extras.py (deflated 75%)
#   adding: numpy/ma/setup.py (deflated 46%)
#   adding: numpy/setup.py (deflated 64%)
#   adding: numpy/lib/ (stored 0%)
#   adding: numpy/lib/type_check.py (deflated 73%)
#   adding: numpy/lib/ufunclike.py (deflated 71%)
#   adding: numpy/lib/info.py (deflated 67%)
#   adding: numpy/lib/__init__.py (deflated 70%)
#   adding: numpy/lib/shape_base.py (deflated 72%)
#   adding: numpy/lib/tests/ (stored 0%)
#   adding: numpy/lib/tests/test_recfunctions.py (deflated 86%)
#   adding: numpy/lib/tests/test_function_base.py (deflated 82%)
#   adding: numpy/lib/tests/test_stride_tricks.py (deflated 78%)
#   adding: numpy/lib/tests/test__datasource.py (deflated 80%)
#   adding: numpy/lib/tests/test_utils.py (deflated 59%)
#   adding: numpy/lib/tests/test_financial.py (deflated 81%)
#   adding: numpy/lib/tests/test_shape_base.py (deflated 81%)
#   adding: numpy/lib/tests/data/ (stored 0%)
#   adding: numpy/lib/tests/data/win64python2.npy (deflated 22%)
#   adding: numpy/lib/tests/data/python3.npy (deflated 23%)
#   adding: numpy/lib/tests/data/py2-objarr.npz (deflated 23%)
#   adding: numpy/lib/tests/data/py3-objarr.npy (deflated 13%)
#   adding: numpy/lib/tests/data/py3-objarr.npz (deflated 21%)
#   adding: numpy/lib/tests/data/py2-objarr.npy (deflated 14%)
#   adding: numpy/lib/tests/test_nanfunctions.py (deflated 86%)
#   adding: numpy/lib/tests/test_io.py (deflated 81%)
#   adding: numpy/lib/tests/test__iotools.py (deflated 81%)
#   adding: numpy/lib/tests/test_type_check.py (deflated 83%)
#   adding: numpy/lib/tests/test_arrayterator.py (deflated 63%)
#   adding: numpy/lib/tests/test_ufunclike.py (deflated 72%)
#   adding: numpy/lib/tests/test_arraypad.py (deflated 89%)
#   adding: numpy/lib/tests/test_packbits.py (deflated 79%)
#   adding: numpy/lib/tests/test_mixins.py (deflated 73%)
#   adding: numpy/lib/tests/test_arraysetops.py (deflated 80%)
#   adding: numpy/lib/tests/test_format.py (deflated 83%)
#   adding: numpy/lib/tests/test_regression.py (deflated 70%)
#   adding: numpy/lib/tests/test__version.py (deflated 74%)
#   adding: numpy/lib/tests/test_polynomial.py (deflated 69%)
#   adding: numpy/lib/tests/test_index_tricks.py (deflated 77%)
#   adding: numpy/lib/tests/test_twodim_base.py (deflated 80%)
#   adding: numpy/lib/arraypad.py (deflated 85%)
#   adding: numpy/lib/function_base.py (deflated 73%)
#   adding: numpy/lib/nanfunctions.py (deflated 81%)
#   adding: numpy/lib/arraysetops.py (deflated 74%)
#   adding: numpy/lib/arrayterator.py (deflated 66%)
#   adding: numpy/lib/format.py (deflated 70%)
#   adding: numpy/lib/_iotools.py (deflated 75%)
#   adding: numpy/lib/twodim_base.py (deflated 73%)
#   adding: numpy/lib/index_tricks.py (deflated 71%)
#   adding: numpy/lib/stride_tricks.py (deflated 66%)
#   adding: numpy/lib/setup.py (deflated 46%)
#   adding: numpy/lib/scimath.py (deflated 78%)
#   adding: numpy/lib/_datasource.py (deflated 75%)
#   adding: numpy/lib/user_array.py (deflated 80%)
#   adding: numpy/lib/polynomial.py (deflated 70%)
#   adding: numpy/lib/mixins.py (deflated 69%)
#   adding: numpy/lib/utils.py (deflated 72%)
#   adding: numpy/lib/financial.py (deflated 72%)
#   adding: numpy/lib/recfunctions.py (deflated 76%)
#   adding: numpy/lib/_version.py (deflated 71%)
#   adding: numpy/lib/npyio.py (deflated 74%)
#   adding: numpy/polynomial/ (stored 0%)
#   adding: numpy/polynomial/hermite.py (deflated 75%)
#   adding: numpy/polynomial/__init__.py (deflated 49%)
#   adding: numpy/polynomial/tests/ (stored 0%)
#   adding: numpy/polynomial/tests/test_chebyshev.py (deflated 82%)
#   adding: numpy/polynomial/tests/test_classes.py (deflated 83%)
#   adding: numpy/polynomial/tests/test_hermite_e.py (deflated 82%)
#   adding: numpy/polynomial/tests/test_legendre.py (deflated 81%)
#   adding: numpy/polynomial/tests/test_polyutils.py (deflated 74%)
#   adding: numpy/polynomial/tests/test_laguerre.py (deflated 82%)
#   adding: numpy/polynomial/tests/test_printing.py (deflated 81%)
#   adding: numpy/polynomial/tests/test_hermite.py (deflated 82%)
#   adding: numpy/polynomial/tests/test_polynomial.py (deflated 83%)
#   adding: numpy/polynomial/hermite_e.py (deflated 75%)
#   adding: numpy/polynomial/_polybase.py (deflated 78%)
#   adding: numpy/polynomial/chebyshev.py (deflated 75%)
#   adding: numpy/polynomial/setup.py (deflated 46%)
#   adding: numpy/polynomial/laguerre.py (deflated 75%)
#   adding: numpy/polynomial/polynomial.py (deflated 75%)
#   adding: numpy/polynomial/polyutils.py (deflated 66%)
#   adding: numpy/polynomial/legendre.py (deflated 75%)
#   adding: numpy/matrixlib/ (stored 0%)
#   adding: numpy/matrixlib/__init__.py (deflated 41%)
#   adding: numpy/matrixlib/tests/ (stored 0%)
#   adding: numpy/matrixlib/tests/test_defmatrix.py (deflated 77%)
#   adding: numpy/matrixlib/tests/test_numeric.py (deflated 51%)
#   adding: numpy/matrixlib/tests/test_multiarray.py (deflated 50%)
#   adding: numpy/matrixlib/tests/test_regression.py (deflated 58%)
#   adding: numpy/matrixlib/defmatrix.py (deflated 77%)
#   adding: numpy/matrixlib/setup.py (deflated 46%)
#   adding: numpy/random/ (stored 0%)
#   adding: numpy/random/info.py (deflated 78%)
#   adding: numpy/random/__init__.py (deflated 75%)
#   adding: numpy/random/tests/ (stored 0%)
#   adding: numpy/random/tests/test_regression.py (deflated 66%)
#   adding: numpy/random/tests/test_random.py (deflated 81%)
#   adding: numpy/random/randomkit.h (deflated 65%)
#   adding: numpy/random/setup.py (deflated 59%)
#   adding: numpy/random/mtrand.so (deflated 65%)
#   adding: numpy/dual.py (deflated 58%)
#   adding: numpy/f2py/ (stored 0%)
#   adding: numpy/f2py/info.py (deflated 19%)
#   adding: numpy/f2py/__init__.py (deflated 59%)
#   adding: numpy/f2py/diagnose.py (deflated 81%)
#   adding: numpy/f2py/src/ (stored 0%)
#   adding: numpy/f2py/src/fortranobject.c (deflated 77%)
#   adding: numpy/f2py/src/fortranobject.h (deflated 66%)
#   adding: numpy/f2py/auxfuncs.py (deflated 78%)
#   adding: numpy/f2py/tests/ (stored 0%)
#   adding: numpy/f2py/tests/src/ (stored 0%)
#   adding: numpy/f2py/tests/src/kind/ (stored 0%)
#   adding: numpy/f2py/tests/src/kind/foo.f90 (deflated 59%)
#   adding: numpy/f2py/tests/src/size/ (stored 0%)
#   adding: numpy/f2py/tests/src/size/foo.f90 (deflated 66%)
#   adding: numpy/f2py/tests/src/assumed_shape/ (stored 0%)
#   adding: numpy/f2py/tests/src/assumed_shape/precision.f90 (deflated 38%)
#   adding: numpy/f2py/tests/src/assumed_shape/foo_use.f90 (deflated 39%)
#   adding: numpy/f2py/tests/src/assumed_shape/foo_free.f90 (deflated 63%)
#   adding: numpy/f2py/tests/src/assumed_shape/.f2py_f2cmap (deflated 7%)
#   adding: numpy/f2py/tests/src/assumed_shape/foo_mod.f90 (deflated 62%)
#   adding: numpy/f2py/tests/src/string/ (stored 0%)
#   adding: numpy/f2py/tests/src/string/char.f90 (deflated 62%)
#   adding: numpy/f2py/tests/src/regression/ (stored 0%)
#   adding: numpy/f2py/tests/src/regression/inout.f90 (deflated 42%)
#   adding: numpy/f2py/tests/src/parameter/ (stored 0%)
#   adding: numpy/f2py/tests/src/parameter/constant_compound.f90 (deflated 47%)
#   adding: numpy/f2py/tests/src/parameter/constant_both.f90 (deflated 81%)
#   adding: numpy/f2py/tests/src/parameter/constant_non_compound.f90 (deflated 50%)
#   adding: numpy/f2py/tests/src/parameter/constant_integer.f90 (deflated 61%)
#   adding: numpy/f2py/tests/src/parameter/constant_real.f90 (deflated 60%)
#   adding: numpy/f2py/tests/src/array_from_pyobj/ (stored 0%)
#   adding: numpy/f2py/tests/src/array_from_pyobj/wrapmodule.c (deflated 74%)
#   adding: numpy/f2py/tests/src/common/ (stored 0%)
#   adding: numpy/f2py/tests/src/common/block.f (deflated 45%)
#   adding: numpy/f2py/tests/src/mixed/ (stored 0%)
#   adding: numpy/f2py/tests/src/mixed/foo.f (deflated 25%)
#   adding: numpy/f2py/tests/src/mixed/foo_fixed.f90 (deflated 45%)
#   adding: numpy/f2py/tests/src/mixed/foo_free.f90 (deflated 32%)
#   adding: numpy/f2py/tests/test_return_integer.py (deflated 81%)
#   adding: numpy/f2py/tests/test_common.py (deflated 54%)
#   adding: numpy/f2py/tests/test_return_complex.py (deflated 79%)
#   adding: numpy/f2py/tests/test_kind.py (deflated 61%)
#   adding: numpy/f2py/tests/test_string.py (deflated 46%)
#   adding: numpy/f2py/tests/test_return_logical.py (deflated 82%)
#   adding: numpy/f2py/tests/test_assumed_shape.py (deflated 63%)
#   adding: numpy/f2py/tests/test_mixed.py (deflated 55%)
#   adding: numpy/f2py/tests/test_return_real.py (deflated 79%)
#   adding: numpy/f2py/tests/test_array_from_pyobj.py (deflated 82%)
#   adding: numpy/f2py/tests/util.py (deflated 73%)
#   adding: numpy/f2py/tests/test_regression.py (deflated 46%)
#   adding: numpy/f2py/tests/test_callback.py (deflated 71%)
#   adding: numpy/f2py/tests/test_return_character.py (deflated 79%)
#   adding: numpy/f2py/tests/test_parameter.py (deflated 83%)
#   adding: numpy/f2py/tests/test_size.py (deflated 64%)
#   adding: numpy/f2py/__version__.py (deflated 40%)
#   adding: numpy/f2py/use_rules.py (deflated 60%)
#   adding: numpy/f2py/capi_maps.py (deflated 78%)
#   adding: numpy/f2py/f90mod_rules.py (deflated 71%)
#   adding: numpy/f2py/f2py_testing.py (deflated 63%)
#   adding: numpy/f2py/cb_rules.py (deflated 79%)
#   adding: numpy/f2py/func2subr.py (deflated 78%)
#   adding: numpy/f2py/rules.py (deflated 81%)
#   adding: numpy/f2py/__main__.py (deflated 49%)
#   adding: numpy/f2py/f2py2e.py (deflated 71%)
#   adding: numpy/f2py/cfuncs.py (deflated 79%)
#   adding: numpy/f2py/setup.py (deflated 58%)
#   adding: numpy/f2py/crackfortran.py (deflated 79%)
#   adding: numpy/f2py/common_rules.py (deflated 65%)
#   adding: numpy-1.13.3.dist-info/ (stored 0%)
#   adding: numpy-1.13.3.dist-info/METADATA (deflated 57%)
#   adding: numpy-1.13.3.dist-info/INSTALLER (stored 0%)
#   adding: numpy-1.13.3.dist-info/top_level.txt (stored 0%)
#   adding: numpy-1.13.3.dist-info/WHEEL (deflated 3%)
#   adding: numpy-1.13.3.dist-info/DESCRIPTION.rst (deflated 43%)
#   adding: numpy-1.13.3.dist-info/RECORD (deflated 57%)
#   adding: numpy-1.13.3.dist-info/metadata.json (deflated 56%)
#   adding: pip-selfcheck.json (stored 0%)
#   adding: s3transfer/ (stored 0%)
#   adding: s3transfer/__init__.py (deflated 75%)
#   adding: s3transfer/compat.py (deflated 59%)
#   adding: s3transfer/download.py (deflated 77%)
#   adding: s3transfer/copies.py (deflated 76%)
#   adding: s3transfer/futures.py (deflated 74%)
#   adding: s3transfer/exceptions.py (deflated 48%)
#   adding: s3transfer/manager.py (deflated 76%)
#   adding: s3transfer/tasks.py (deflated 72%)
#   adding: s3transfer/delete.py (deflated 63%)
#   adding: s3transfer/subscribers.py (deflated 64%)
#   adding: s3transfer/upload.py (deflated 78%)
#   adding: s3transfer/utils.py (deflated 73%)
#   adding: sam/ (stored 0%)
#   adding: sam/template.yaml (deflated 57%)
#   adding: sam/swagger.yaml (deflated 78%)
#   adding: sam/template-out.yaml (deflated 60%)
#   adding: setup.cfg (stored 0%)
#   adding: six.py (deflated 75%)
#   adding: six.pyc (deflated 63%)
#   adding: swagger.yaml.template (deflated 78%)
#   adding: synset.txt (deflated 54%)
#   adding: template-out.yaml (deflated 60%)
#   adding: template.yaml.template (deflated 56%)

# %%
func_name = "MX-LAMBDA-GEOLOCATION-LambdaFunction-5MR66LKLX01L"
# !aws lambda update-function-code --function-name $func_name --zip-file fileb://$code_zip_name  --region us-west-2
# Out:
# {
#     "Runtime": "python2.7",
#     "CodeSha256": "MSLihL4UA7gekyRqdx0M7923eO6HOOjO9z+BR37aJko=",
#     "FunctionName": "MX-LAMBDA-GEOLOCATION-LambdaFunction-5MR66LKLX01L",
#     "LastModified": "2017-11-16T23:59:34.803+0000",
#     "VpcConfig": {
#         "SubnetIds": [],
#         "SecurityGroupIds": []
#     },
#     "Version": "$LATEST",
#     "CodeSize": 47715512,
#     "Timeout": 120,
#     "Role": "arn:aws:iam::209028685534:role/MX-LAMBDA-GEOLOCATION-LambdaFunctionRole-1A1Z1W7NFJ3LF",
#     "Handler": "lambda_function.lambda_handler",
#     "MemorySize": 3008,
#     "Description": "MXNet Lambda Function",
#     "FunctionArn": "arn:aws:lambda:us-west-2:209028685534:function:MX-LAMBDA-GEOLOCATION-LambdaFunction-5MR66LKLX01L"
# }

# %% [markdown]
# # Swagger File

# %%
account_id = 'MY_ACC_ID'
region = 'us-west-2'

# !sed -e 's/<<region>>/$region/g' swagger.yaml.template > swagger.yaml
# !sed -i -e 's/<<account-id>>/$account_id/g' swagger.yaml

# %% [markdown]
# # Upload Code and YAML files to S3

# %%
bucket_loc = "s3://smallya-testw/samtest/" # **NOTE** Make sure bucket is in the same region as region above
# !aws s3 cp $code_zip_name $bucket_loc
# !aws s3 cp swagger.yaml $bucket_loc
# Out:
# upload: ./mxnet_lambda_code.zip to s3://smallya-testw/samtest/mxnet_lambda_code.zip
# upload: ./swagger.yaml to s3://smallya-testw/samtest/swagger.yaml

# %% [markdown]
# # Template File

# %%
definition_url = bucket_loc + 'swagger.yaml' # swagger file location in s3
code_uri = bucket_loc + code_zip_name  # code location in s3
definition_url = definition_url.replace(':', '\:').replace('/', '\/')
code_uri = code_uri.replace(':', '\:').replace('/', '\/')

# !sed -e 's/<<def-uri>>/$definition_url/g' template.yaml.template > template.yaml
# !sed -i -e 's/<<code-uri>>/$code_uri/g' template.yaml

# %% [markdown]
# # Deply using SAM

# %%
# !aws cloudformation package \
 --template-file template.yaml \
 --output-template-file template-out.yaml \
 --s3-bucket $bucket_loc
# Out:
# Successfully packaged artifacts and wrote output template to file template-out.yaml.
# Execute the following command to deploy the packaged template
# aws cloudformation deploy --template-file /home/ubuntu/workspace/geolocation/lambda-sam/template-out.yaml --stack-name <YOUR STACK NAME>

# %%
stack_name = "MX-LAMBDA-GEOLOCATION"

# !aws cloudformation deploy \
--template-file template-out.yaml \
--stack-name $stack_name \
--capabilities CAPABILITY_IAM \
--region $region
# Out:
# Waiting for changeset to be created..
# Waiting for stack create/update to complete
# Successfully created/updated stack - MX-LAMBDA-GEOLOCATION

# %%
api_endpoint = !aws cloudformation describe-stacks --stack-name $stack_name --region $region | python -c 'import json,sys;obj=json.load(sys.stdin);print obj["Stacks"][0]["Outputs"][0]["OutputValue"];'
print api_endpoint
# Out:
# ['https://laktzr3bd2.execute-api.us-west-2.amazonaws.com/prod']

# %% [markdown]
# <img src='https://www.svalbardblues.com/wp-content/uploads/2015/09/Longyearbyen-Svalbard-Spitsbergen-DSB.jpg'/>

# %%
import requests
import json

img_url = 'https://www.svalbardblues.com/wp-content/uploads/2015/09/Longyearbyen-Svalbard-Spitsbergen-DSB.jpg'
#api_endpoint = ['https://udgz5whroh.execute-api.us-east-1.amazonaws.com/prod']
#api_endpoint = ['https://jlym62q78c.execute-api.us-west-2.amazonaws.com/prod']
url = api_endpoint[0]+ "/predict?url=" + img_url

print url

# Lets curl and test the endpoint
# !curl $url
# Out:
# https://laktzr3bd2.execute-api.us-west-2.amazonaws.com/prod/predict?url=https://www.svalbardblues.com/wp-content/uploads/2015/09/Longyearbyen-Svalbard-Spitsbergen-DSB.jpg
# {"address": "Svalbard, Norge", "latlng": "(78.7198519, 20.3493328)"}

# %%
import requests
import json

img_url = 'http://www.liveroof.com/wp-content/uploads/2015/01/Javits-Center_Exterior-Dusk_DS1-990x360.jpg'
#img_url = 'https://www.svalbardblues.com/wp-content/uploads/2015/09/Longyearbyen-Svalbard-Spitsbergen-DSB.jpg'

#api_endpoint = ['https://udgz5whroh.execute-api.us-east-1.amazonaws.com/prod']
url = api_endpoint[0]+ "/predict?url=" + img_url

# Lets curl and test the endpoint
# !curl $url
# Out:
# {"address": "IAC Building, 11th Avenue, Chelsea, Manhattan Community Board 4, New York County, NYC, New York, 10011, United States of America", "latlng": "(40.74557055, -74.0077509293129)"}

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
location = geolocator.reverse("52.509669, 13.376294")
location.address
# Out:
# u'Backwerk, Potsdamer Platz, Tiergarten, Mitte, Berlin, 10785, Deutschland'
